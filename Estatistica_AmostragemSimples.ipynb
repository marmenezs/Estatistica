# %% [markdown]
# Estatística - Amostragem Simples

# %%
import pandas as pd
import numpy as np

# %%
#carregando a base de dados
dados = pd.read_csv('iris.csv')
dados.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#criando um conjunto de valores aleatórios randômicos com valores 0 e 1
np.random.seed(2345)
amostra = np.random.choice(a=[0,1], size=150, replace=True, p=[0.7,0.3])
amostra
#verificando a quantidade de zeros
len(amostra[amostra == 0])
# Out:
# 101

# %%
#alocando os dados do conjunto 'iris' nos valores gerados randomicamente
#alocando nos zeros
dados_final = dados.loc[amostra == 0]  #também pode alocar no 1
dados_final
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# ...
